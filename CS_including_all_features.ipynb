# %% [markdown]
# ##NYS Hospitalizations Records - data preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def transform_column_names(dataframe):
    """Convert column names in a dataframe to lower case and join multi-word names to a single-word name"""
    
    dataframe.columns = [x.lower() for x in dataframe.columns]
    dataframe.columns = [x.replace(" ","") for x in dataframe.columns]
    return dataframe.columns

# %%
def series_to_dataframe(values,index_,value_):
    """Converting pandas series to dataframe with two columns:
    col1 - series index
    col2 - series value
    index_ and value_ are strings (column names of returned dataframe)"""
    
    col1 = values.index.tolist()
    s1 = pd.Series(col1)

    col2 = []
    for value in values:
        col2.append(value)
    s2 = pd.Series(col2)

    df = pd.concat([s1,s2],axis=1)
    df.columns = [index_,value_]
    return df

# %%
def dataframe_subset(dataframe,feature,selection):
    """Selecting a subset of dataframe with feature set to selection criteria and reindexing a dataframe
    feature - string
    selection - variable/feature type"""
    
    df = dataframe[dataframe[feature] == selection].reset_index(drop = True)
    return df

# %%
def NaNprob_per_col(dataframe):
    """Find probability of NaN values in each column of a dataframe
    return a 2-column dataframe: col1 - feature, col2 - NaN probability """
    
    nv = dataframe.isnull().sum()/len(dataframe)
    NaN_val = series_to_dataframe(nv,'feature','NaN_perc')
    return NaN_val

# %%
def remove_columns(dataframe,features):
    """Deletes columns in dataframe
    features - list of column names that need to be removed from a dataframe"""
    for feature in features:
        if feature in dataframe:
            del dataframe[feature]
        else:
            print feature + ' not in ' + dataframe
    return dataframe

# %%
def dropna_(dataframe):
    """Dropping NaNs"""
    
    dataframe = dataframe.dropna()
    return dataframe

# %%
pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',300)

# %%
# !ls -l *.csv
# Out:
# -rw-r--r--@ 1 iwonapawelczak  staff  1008218962 Mar 11  2015 Hospital_Inpatient_Discharges__SPARCS_De-Identified___2011.csv
# -rw-r--r--@ 1 iwonapawelczak  staff   913524471 Mar 11  2015 Hospital_Inpatient_Discharges__SPARCS_De-Identified___2013.csv
# -rw-r--r--  1 iwonapawelczak  staff     4969037 Jun 23  2015 NY_CesareanSection_2011.csv

# %%
df = pd.read_csv("Hospital_Inpatient_Discharges__SPARCS_De-Identified___2011.csv",low_memory = False)

# %%
df.head()
# Out:
#   Health Service Area Hospital County  Operating Certificate Number  \
# 0      Capital/Adiron          Albany                        101000
# 1      Capital/Adiron          Albany                        101000
# 2      Capital/Adiron          Albany                        101000
# 3      Capital/Adiron          Albany                        101000
# 4      Capital/Adiron          Albany                        101000
#
#    Facility ID                   Facility Name Age Group Zip Code - 3 digits  \
# 0            1  Albany Medical Center Hospital  30 to 49                 123
# 1            1  Albany Medical Center Hospital   0 to 17                 120
# 2            1  Albany Medical Center Hospital  18 to 29                 121
# 3            1  Albany Medical Center Hospital   0 to 17                 122
# 4            1  Albany Medical Center Hospital  18 to 29                 122
#
#   Gender                    Race          Ethnicity Length of Stay  \
# 0      M                   White  Not Span/Hispanic              3
# 1      M                   White  Not Span/Hispanic              1
# 2      F                   White  Not Span/Hispanic              2
# 3      F  Black/African American  Not Span/Hispanic              1
# 4      F  Black/African American  Not Span/Hispanic              3
#
#   Admit Day of Week Type of Admission                   Patient Disposition  \
# 0               FRI         Emergency                     Home or Self Care
# 1               FRI         Emergency                     Home or Self Care
# 2               FRI         Emergency                     Home or Self Care
# 3               FRI         Emergency                               Expired
# 4               FRI         Emergency  Psychiatric Hospital or Unit of Hosp
#
#    Discharge Year Discharge Day of Week  CCS Diagnosis Code  \
# 0            2011                   MON                  50
# 1            2011                   SAT                   8
# 2            2011                   SUN                 149
# 3            2011                   FRI                 238
# 4            2011                   MON                 241
#
#   CCS Diagnosis Description  CCS Procedure Code CCS Procedure Description  \
# 0          DIABETES W/COMPL                  58              HEMODIALYSIS
# 1          OTHER INFECTIONS                 162   OT OR THER PRC ON JOINT
# 2     BILIARY TRACT DISEASE                  84    CHOLECYSTECTOMY/EXPLOR
# 3     SURGCL/MED CARE COMPL                 216    RESP INTUB/MECH VENTIL
# 4    PSYCHOTROPIC POISONING                   0                   NO PROC
#
#    APR DRG Code                                APR DRG Description  \
# 0           420                                           DIABETES
# 1           710  INFECTIOUS & PARASITIC DISEASES INCLUDING HIV ...
# 2           263                       LAPAROSCOPIC CHOLECYSTECTOMY
# 3           132  BPD & OTH CHRONIC RESPIRATORY DISEASES ARISING...
# 4           812                      POISONING OF MEDICINAL AGENTS
#
#    APR MDC Code                                APR MDC Description  \
# 0            10  Endocrine, Nutritional and Metabolic Diseases ...
# 1            18  Infectious and Parasitic Diseases, Systemic or...
# 2             7  Diseases and Disorders of the Hepatobiliary Sy...
# 3             4   Diseases and Disorders of the Respiratory System
# 4            21  Poisonings, Toxic Effects, Other Injuries and ...
#
#    APR Severity of Illness Code APR Severity of Illness Description  \
# 0                             4                             Extreme
# 1                             2                            Moderate
# 2                             2                            Moderate
# 3                             4                             Extreme
# 4                             2                            Moderate
#
#   APR Risk of Mortality APR Medical Surgical Description Source of Payment 1  \
# 0                 Major                          Medical            Medicare
# 1                 Minor                         Surgical   Insurance Company
# 2                 Minor                         Surgical   Insurance Company
# 3                 Major                          Medical            Medicaid
# 4                 Minor                          Medical   Insurance Company
#
#   Source of Payment 2 Source of Payment 3  Attending Provider License Number  \
# 0            Self-Pay                 NaN                             236885
# 1            Self-Pay                 NaN                             244921
# 2            Self-Pay                 NaN                             204436
# 3            Self-Pay                 NaN                             251930
# 4            Medicaid            Self-Pay                               3814
#
#    Operating Provider License Number  Other Provider License Number  \
# 0                             236885                            NaN
# 1                             252318                            NaN
# 2                             204436                            NaN
# 3                             251040                            NaN
# 4                                NaN                            NaN
#
#    Birth Weight Abortion Edit Indicator Emergency Department Indicator  \
# 0             0                       N                              Y
# 1             0                       N                              Y
# 2             0                       N                              Y
# 3             0                       N                              Y
# 4             0                       N                              Y
#
#   Total Charges Total Costs
# 0     $39826.76   $10488.51
# 1      $9553.33    $2528.70
# 2     $21694.42    $6705.37
# 3     $14000.54    $3890.69
# 4     $12260.63    $4466.34

# %%
# All hospitalizations
print df.shape
print df.dtypes
print df.columns
# Out:
# (2584770, 39)
# Health Service Area                     object
# Hospital County                         object
# Operating Certificate Number           float64
# Facility ID                            float64
# Facility Name                           object
# Age Group                               object
# Zip Code - 3 digits                     object
# Gender                                  object
# Race                                    object
# Ethnicity                               object
# Length of Stay                          object
# Admit Day of Week                       object
# Type of Admission                       object
# Patient Disposition                     object
# Discharge Year                           int64
# Discharge Day of Week                   object
# CCS Diagnosis Code                       int64
# CCS Diagnosis Description               object
# CCS Procedure Code                       int64
# CCS Procedure Description               object
# APR DRG Code                             int64
# APR DRG Description                     object
# APR MDC Code                             int64
# APR MDC Description                     object
# APR Severity of Illness Code             int64
# APR Severity of Illness Description     object
# APR Risk of Mortality                   object
# APR Medical Surgical Description        object
# Source of Payment 1                     object
# Source of Payment 2                     object
# Source of Payment 3                     object
# Attending Provider License Number      float64
# Operating Provider License Number      float64
# Other Provider License Number          float64
# Birth Weight                             int64
# Abortion Edit Indicator                 object
# Emergency Department Indicator          object
# Total Charges                           object
# Total Costs                             object
# dtype: object
# Index([u'Health Service Area', u'Hospital County', u'Operating Certificate Number', u'Facility ID', u'Facility Name', u'Age Group', u'Zip Code - 3 digits', u'Gender', u'Race', u'Ethnicity', u'Length of Stay', u'Admit Day of Week', u'Type of Admission', u'Patient Disposition', u'Discharge Year', u'Discharge Day of Week', u'CCS Diagnosis Code', u'CCS Diagnosis Description', u'CCS Procedure Code', u'CCS Procedure Description', u'APR DRG Code', u'APR DRG Description', u'APR MDC Code', u'APR MDC Description', u'APR Severity of Illness Code', u'APR Severity of Illness Description', u'APR Risk of Mortality', u'APR Medical Surgical Description', u'Source of Payment 1', u'Source of Payment 2', u'Source of Payment 3', u'Attending Provider License Number', u'Operating Provider License Number', u'Other Provider License Number', u'Birth Weight', u'Abortion Edit Indicator', u'Emergency Department Indicator', u'Total Charges', u'Total Costs'], dtype='object')

# %%
transform_column_names(df)
# Out:
# Index([u'healthservicearea', u'hospitalcounty', u'operatingcertificatenumber', u'facilityid', u'facilityname', u'agegroup', u'zipcode-3digits', u'gender', u'race', u'ethnicity', u'lengthofstay', u'admitdayofweek', u'typeofadmission', u'patientdisposition', u'dischargeyear', u'dischargedayofweek', u'ccsdiagnosiscode', u'ccsdiagnosisdescription', u'ccsprocedurecode', u'ccsproceduredescription', u'aprdrgcode', u'aprdrgdescription', u'aprmdccode', u'aprmdcdescription', u'aprseverityofillnesscode', u'aprseverityofillnessdescription', u'aprriskofmortality', u'aprmedicalsurgicaldescription', u'sourceofpayment1', u'sourceofpayment2', u'sourceofpayment3', u'attendingproviderlicensenumber', u'operatingproviderlicensenumber', u'otherproviderlicensenumber', u'birthweight', u'abortioneditindicator', u'emergencydepartmentindicator', u'totalcharges', u'totalcosts'], dtype='object')

# %%
CS = dataframe_subset(df,'ccsproceduredescription','CESAREAN SECTION')

# %%
# Check for data dimentions/stats, types, and column names
print "Data shape: ", CS.shape
print "Data types: ", CS.dtypes
print "Columns: ", CS.columns
# Out:
# Data shape:  (79217, 39)
# Data types:  healthservicearea                   object
# hospitalcounty                      object
# operatingcertificatenumber         float64
# facilityid                         float64
# facilityname                        object
# agegroup                            object
# zipcode-3digits                     object
# gender                              object
# race                                object
# ethnicity                           object
# lengthofstay                        object
# admitdayofweek                      object
# typeofadmission                     object
# patientdisposition                  object
# dischargeyear                        int64
# dischargedayofweek                  object
# ccsdiagnosiscode                     int64
# ccsdiagnosisdescription             object
# ccsprocedurecode                     int64
# ccsproceduredescription             object
# aprdrgcode                           int64
# aprdrgdescription                   object
# aprmdccode                           int64
# aprmdcdescription                   object
# aprseverityofillnesscode             int64
# aprseverityofillnessdescription     object
# aprriskofmortality                  object
# aprmedicalsurgicaldescription       object
# sourceofpayment1                    object
# sourceofpayment2                    object
# sourceofpayment3                    object
# attendingproviderlicensenumber     float64
# operatingproviderlicensenumber     float64
# otherproviderlicensenumber         float64
# birthweight                          int64
# abortioneditindicator               object
# emergencydepartmentindicator        object
# totalcharges                        object
# totalcosts                          object
# dtype: object
# Columns:  Index([u'healthservicearea', u'hospitalcounty', u'operatingcertificatenumber', u'facilityid', u'facilityname', u'agegroup', u'zipcode-3digits', u'gender', u'race', u'ethnicity', u'lengthofstay', u'admitdayofweek', u'typeofadmission', u'patientdisposition', u'dischargeyear', u'dischargedayofweek', u'ccsdiagnosiscode', u'ccsdiagnosisdescription', u'ccsprocedurecode', u'ccsproceduredescription', u'aprdrgcode', u'aprdrgdescription', u'aprmdccode', u'aprmdcdescription', u'aprseverityofillnesscode', u'aprseverityofillnessdescription', u'aprriskofmortality', u'aprmedicalsurgicaldescription', u'sourceofpayment1', u'sourceofpayment2', u'sourceofpayment3', u'attendingproviderlicensenumber', u'operatingproviderlicensenumber', u'otherproviderlicensenumber', u'birthweight', u'abortioneditindicator', u'emergencydepartmentindicator', u'totalcharges', u'totalcosts'], dtype='object')

# %%
CS.head()
# Out:
#   healthservicearea hospitalcounty  operatingcertificatenumber  facilityid  \
# 0    Capital/Adiron         Albany                      101000           1
# 1    Capital/Adiron         Albany                      101000           1
# 2    Capital/Adiron         Albany                      101000           1
# 3    Capital/Adiron         Albany                      101000           1
# 4    Capital/Adiron         Albany                      101000           1
#
#                      facilityname  agegroup zipcode-3digits gender  \
# 0  Albany Medical Center Hospital  30 to 49             120      F
# 1  Albany Medical Center Hospital  18 to 29             128      F
# 2  Albany Medical Center Hospital  30 to 49             OOS      F
# 3  Albany Medical Center Hospital  30 to 49             120      F
# 4  Albany Medical Center Hospital  30 to 49             122      F
#
#                      race          ethnicity lengthofstay admitdayofweek  \
# 0                   White  Not Span/Hispanic            8            SAT
# 1                   White  Not Span/Hispanic            4            SAT
# 2                   White  Not Span/Hispanic           18            SUN
# 3                   White  Not Span/Hispanic           17            WED
# 4  Black/African American  Not Span/Hispanic           11            FRI
#
#   typeofadmission                 patientdisposition  dischargeyear  \
# 0       Emergency                  Home or Self Care           2011
# 1       Emergency                  Home or Self Care           2011
# 2       Emergency  Inpatient Rehabilitation Facility           2011
# 3       Emergency       Home w/ Home Health Services           2011
# 4       Emergency                  Home or Self Care           2011
#
#   dischargedayofweek  ccsdiagnosiscode ccsdiagnosisdescription  \
# 0                SUN               190          FETAL DISTRESS
# 1                WED               182     PREGNANCY HEMORRHAG
# 2                THU               195  OTH COMP BIRTH/PUERPRM
# 3                SAT               195  OTH COMP BIRTH/PUERPRM
# 4                TUE               182     PREGNANCY HEMORRHAG
#
#    ccsprocedurecode ccsproceduredescription  aprdrgcode  aprdrgdescription  \
# 0               134        CESAREAN SECTION         540  CESAREAN DELIVERY
# 1               134        CESAREAN SECTION         540  CESAREAN DELIVERY
# 2               134        CESAREAN SECTION         540  CESAREAN DELIVERY
# 3               134        CESAREAN SECTION         540  CESAREAN DELIVERY
# 4               134        CESAREAN SECTION         540  CESAREAN DELIVERY
#
#    aprmdccode                         aprmdcdescription  \
# 0          14  Pregnancy, Childbirth and the Puerperium
# 1          14  Pregnancy, Childbirth and the Puerperium
# 2          14  Pregnancy, Childbirth and the Puerperium
# 3          14  Pregnancy, Childbirth and the Puerperium
# 4          14  Pregnancy, Childbirth and the Puerperium
#
#    aprseverityofillnesscode aprseverityofillnessdescription  \
# 0                         3                           Major
# 1                         2                        Moderate
# 2                         4                         Extreme
# 3                         3                           Major
# 4                         3                           Major
#
#   aprriskofmortality aprmedicalsurgicaldescription   sourceofpayment1  \
# 0              Minor                      Surgical  Insurance Company
# 1              Minor                      Surgical  Insurance Company
# 2              Major                      Surgical  Insurance Company
# 3              Major                      Surgical  Insurance Company
# 4           Moderate                      Surgical  Insurance Company
#
#     sourceofpayment2 sourceofpayment3  attendingproviderlicensenumber  \
# 0           Medicaid         Self-Pay                          114221
# 1  Insurance Company         Self-Pay                          196010
# 2           Self-Pay              NaN                          216291
# 3           Medicaid         Self-Pay                          149551
# 4           Medicaid         Self-Pay                          148296
#
#    operatingproviderlicensenumber  otherproviderlicensenumber  birthweight  \
# 0                          171241                      114221            0
# 1                          254742                      254742            0
# 2                          149551                         NaN            0
# 3                          149551                      149551            0
# 4                          148296                      148296            0
#
#   abortioneditindicator emergencydepartmentindicator totalcharges totalcosts
# 0                     N                            Y    $25584.21  $11622.46
# 1                     N                            Y    $41648.20  $11220.69
# 2                     N                            Y   $143534.01  $50545.41
# 3                     N                            Y   $128973.98  $48055.58
# 4                     N                            Y    $76803.96  $27072.54

# %%
CS['lengthofstay'] = CS.lengthofstay.str.replace('+', '').astype(float)

# %%
CS['ccsdiagnosiscode'] = df['ccsdiagnosiscode'].astype(float)

# %%
CS['totalcharges'] = CS['totalcharges'].str.replace(r'$','').astype(float)
CS['totalcosts'] = CS['totalcosts'].str.replace(r'$','').astype(float)

# %%
nan_values = CS.isnull().sum()

# %%
nan_values
# Out:
# healthservicearea                      9
# hospitalcounty                         9
# operatingcertificatenumber             9
# facilityid                             9
# facilityname                           0
# agegroup                               0
# zipcode-3digits                      125
# gender                                 0
# race                                   0
# ethnicity                              0
# lengthofstay                           0
# admitdayofweek                         9
# typeofadmission                        0
# patientdisposition                     1
# dischargeyear                          0
# dischargedayofweek                     9
# ccsdiagnosiscode                       0
# ccsdiagnosisdescription                0
# ccsprocedurecode                       0
# ccsproceduredescription                0
# aprdrgcode                             0
# aprdrgdescription                      0
# aprmdccode                             0
# aprmdcdescription                      0
# aprseverityofillnesscode               0
# aprseverityofillnessdescription        3
# aprriskofmortality                     3
# aprmedicalsurgicaldescription          0
# sourceofpayment1                       0
# sourceofpayment2                   31346
# sourceofpayment3                   68721
# attendingproviderlicensenumber         9
# operatingproviderlicensenumber         9
# otherproviderlicensenumber         65636
# birthweight                            0
# abortioneditindicator                  0
# emergencydepartmentindicator           0
# totalcharges                           0
# totalcosts                             0
# dtype: int64

# %%
# Check for columns that contain large numbers of missing values - set criteria for column removal based on NaNs
NaN_prob = NaNprob_per_col(CS)

# %%
NaN_prob
# Out:
#                             feature  NaN_perc
# 0                 healthservicearea  0.000114
# 1                    hospitalcounty  0.000114
# 2        operatingcertificatenumber  0.000114
# 3                        facilityid  0.000114
# 4                      facilityname  0.000000
# 5                          agegroup  0.000000
# 6                   zipcode-3digits  0.001578
# 7                            gender  0.000000
# 8                              race  0.000000
# 9                         ethnicity  0.000000
# 10                     lengthofstay  0.000000
# 11                   admitdayofweek  0.000114
# 12                  typeofadmission  0.000000
# 13               patientdisposition  0.000013
# 14                    dischargeyear  0.000000
# 15               dischargedayofweek  0.000114
# 16                 ccsdiagnosiscode  0.000000
# 17          ccsdiagnosisdescription  0.000000
# 18                 ccsprocedurecode  0.000000
# 19          ccsproceduredescription  0.000000
# 20                       aprdrgcode  0.000000
# 21                aprdrgdescription  0.000000
# 22                       aprmdccode  0.000000
# 23                aprmdcdescription  0.000000
# 24         aprseverityofillnesscode  0.000000
# 25  aprseverityofillnessdescription  0.000038
# 26               aprriskofmortality  0.000038
# 27    aprmedicalsurgicaldescription  0.000000
# 28                 sourceofpayment1  0.000000
# 29                 sourceofpayment2  0.395698
# 30                 sourceofpayment3  0.867503
# 31   attendingproviderlicensenumber  0.000114
# 32   operatingproviderlicensenumber  0.000114
# 33       otherproviderlicensenumber  0.828560
# 34                      birthweight  0.000000
# 35            abortioneditindicator  0.000000
# 36     emergencydepartmentindicator  0.000000
# 37                     totalcharges  0.000000
# 38                       totalcosts  0.000000

# %%
# remove empty columns which have large numbers of NaNs
# it would suffice to remove if 30% of data is missing but zip-code has 0.16% NaNs and it is collinear with other 
# variables e.g., hospitals so can be removed here as well
features_to_remove = NaN_prob[NaN_prob['NaN_perc'] >= 0.001]

# %%
items = features_to_remove['feature'].tolist()
print 'List of features to be removed from CS dataframe based on NaNs condition:'
print items
# Out:
# List of features to be removed from CS dataframe based on NaNs condition:
# ['zipcode-3digits', 'sourceofpayment2', 'sourceofpayment3', 'otherproviderlicensenumber']

# %%
# Number of columns before removal
CS.shape
# Out:
# (79217, 39)

# %%
# Removing columns which are mostly empty + zip
CS = remove_columns(CS,items)

# %%
# After empty columns removal
CS.shape
# Out:
# (79217, 35)

# %%
CS = dropna_(CS)

# %%
# After removing NaN values - data for further analysis
CS.shape
# Out:
# (79204, 35)

# %%
CS.to_csv("NY_CesareanSection_2011_70kevents.csv")
