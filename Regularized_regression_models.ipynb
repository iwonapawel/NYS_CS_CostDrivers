# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as smf
# %matplotlib inline

# %%
df = pd.read_csv("NY_CesareanSection_2011_70kevents.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 healthservicearea hospitalcounty  operatingcertificatenumber  \
# 0           0    Capital/Adiron         Albany                      101000
# 1           1    Capital/Adiron         Albany                      101000
# 2           2    Capital/Adiron         Albany                      101000
# 3           3    Capital/Adiron         Albany                      101000
# 4           4    Capital/Adiron         Albany                      101000
#
#    facilityid                    facilityname  agegroup gender  \
# 0           1  Albany Medical Center Hospital  30 to 49      F
# 1           1  Albany Medical Center Hospital  18 to 29      F
# 2           1  Albany Medical Center Hospital  30 to 49      F
# 3           1  Albany Medical Center Hospital  30 to 49      F
# 4           1  Albany Medical Center Hospital  30 to 49      F
#
#                      race          ethnicity    ...      aprriskofmortality  \
# ...
